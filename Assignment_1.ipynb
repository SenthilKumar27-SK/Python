# %%
#Write a Python program that takes the length and width of a rectangle from the user and prints its area.
l=int(input("enter a length"))
w=int(input("enter a width"))
print("enter a length",l*w)
print("enter a width",w*l)
# Out:
# enter a length50
# enter a width20
# enter a length 1000
# enter a width 1000

# %%
#Write a program that asks the user for the side of a square and prints its perimeter.
S=int(input("enter the Side of the square ", ))
p=s*4
print("perimeter of the square",s*4)
# Out:
# enter the Side of the square 15
# perimeter of the square 60

# %%
#Take the base and height of a triangle as input and print its area.
B=int(input("enter the base of the triangle: "))
H=int(input("enter the height of a triangle: "))
triangle_area=(1/2)*B*H
print("the area of the triangle is:",triangle_area)
# Out:
# enter the base of the triangle: 10
# enter the height of a triangle: 20
# the area of the triangle is: 100.0

# %%
#Write a program that asks the user for the radius of a circle and prints its circumference. (Use 3.14 for π).
radius = float(input("Enter the radius of the circle: "))
circumference = 2 * 3.14 * radius
print("The circumference of the circle is:", circumference)
# Out:
# Enter the radius of the circle: 10
# The circumference of the circle is: 62.800000000000004

# %%
#Take Principal (P), Rate (R), and Time (T) as input from the user and print the Simple Interest.
p=float(input("enter the principal amount: "))
r=float(input("enter the rate of the interest in (percentage)"))
t=float(input("enter the time period (in year); "))
simple_interest=(p*r*t)/100
print("the simple interest is :",simple_interest)
# Out:
# enter the principal amount: 10
# enter the rate of the interest in (percentage)20
# enter the time period (in year); 12
# the simple interest is : 24.0
