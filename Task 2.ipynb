# %%
#declarationa=66
A=12
num=132
num1=456
stu_name='senthil'
_stu_id=123
Num11=768


print(num)
print(num1)
print(Num11)
# Out:
# 132
# 456
# 768

# %%
a=6j+3
type(a)
# Out:
# complex

# %%
#write a program to read student name,id,email,3 subject marks out of 100 and display they details in below format

student_details="******Student details******"
id=int(input("enter the id"))
name=str(input("enter the name"))
email=str(input("enter the email"))
sub1=int(input("enter the subject 1"))
sub2=int(input("enter the subject 2"))
sub3=int(input("enter the subject 3"))
total=sub1+sub2+sub3
percentage=total/3
wishes="******All the best******"
print(student_details)
print(id)
print(name)
print(email)
print(sub1)
print(sub2)
print(sub3)
print(total)
print(percentage)
print(wishes)
# Out:
# enter the id 55
# enter the name senthil kumar
# enter the email senthil123@gmail.com
# enter the subject 1 99
# enter the subject 2 98
# enter the subject 3 95
# ******Student details******
# 55
# senthil kumar
# senthil123@gmail.com
# 99
# 98
# 95
# 292
# 97.33333333333333
# ******All the best******

# %%
#read a float value from user then convert that value to integer
va=float(input("enter the value"))
print(type(va))
u_va=int(va)
print(type(u_va))
# Out:
# enter the value 10.5
# <class 'float'>
# <class 'int'>

# %%
#invalid variable declarations:
stu nam
