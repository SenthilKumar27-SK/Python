# %%
#Write a program to accept two integer numbers from the user and calculate their product.

A=int(input("enter the value of A"))
B=int(input("enter the value of B"))
C=A*B
print("Calculate product values is:",C)
# Out:
# enter the value of A 10
# enter the value of B 50
# Calculate product values is: 500

# %%
#Write a program to display four string “My, “Name“, “Is“, “James” as “My**Name**Is**James“.
#Use the print() function to format the given words in the specified format. Display the ** separator between each string.

A='My'
B='Name'
C='is'
D='James'
print(A,B,C,D,sep="**")
# Out:
# My**Name**is**James

# %%
#Display Decimal Number to Octal using print() function
num=8
print("Octal representation:",'%o' % num)
# Out:
# Octal representation: 10

# %%
#Display Float Number with 2 Decimal Places
num=458.541315
print('%.2f' %num)
# Out:
# 458.54

# %%
#Accept a list of 5 float numbers as an input from the user
numbers = []

numbers.append(float(input("Enter number 1: ")))
numbers.append(float(input("Enter number 2: ")))
numbers.append(float(input("Enter number 3: ")))
numbers.append(float(input("Enter number 4: ")))
numbers.append(float(input("Enter number 5: ")))

print(numbers)
# Out:
# Enter number 1:  10.5
# Enter number 2:  2.5
# Enter number 3:  56.5
# Enter number 4:  45.5
# Enter number 5:  15.5
# [10.5, 2.5, 56.5, 45.5, 15.5]

# %%
#Write all content of a file into a new file by skipping line number 5
f1 = open("test.txt", "r")
f2 = open("new_file.txt", "w")

count = 1
for line in f1:
    if count != 5:
        f2.write(line)
        print(line, end="")
    count += 1

f1.close()
f2.close()
# Out:
# Line1
# Line2
# Line3
# Line4

# %%
#Accept any three string from one input() call
str1, str2, str3 = input("Enter three strings: ").split()

print(str1, str2, str3)
# Out:
# Enter three strings:  dog cat birds
# dog cat birds

# %%
#Write a program to use the string.format() method to format the following three variables according to the expected output.
total_Money = 1000
quantity = 3
price = 450
Spending_money= "I have {1} dollars so I can buy {0} football for {2:.2f} dollars."
print(Spending_money.format(quantity, totalMoney, price))
# Out:
# I have 1000 dollars so I can buy 3 football for 450.00 dollars.

# %%
#Write a program to check if the given file is empty or not

import os

filename = "test.txt"

if not os.path.isfile(filename):
    print("File not found")
else:
    if os.stat(filename).st_size == 0:
        print("File is empty")
    else:
        print("File is not empty")
# Out:
# File not found

# %%
#Create a test.txt file and add the below content to it.
with open("test.txt", "w") as f:
    f.write("Line1\n")
    f.write("Line2\n")
    f.write("Line3\n")
    f.write("Line4\n")

with open("test.txt", "r") as fp:
    lines = fp.readlines()
    print(lines[2])
# Out:
# Line3

# %%
#Ask the user for a numerator and a denominator.
#Calculate the percentage and display it with two decimal places followed by a percent sign (e.g., 75.50%).
numerator = float(input("Enter numerator: "))
denominator = float(input("Enter denominator: "))

percentage = (numerator / denominator) * 100

print("Percentage: {:.2f}%".format(percentage))
# Out:
# Enter numerator:  75
# Enter denominator:  10
# Percentage: 750.00%

# %%
#Create a simple interactive menu with options like “1. Say Hello”, “2. 
#Calculate Square”, “3. Exit”. Based on the user’s input, perform the corresponding action
while True:
    print("\nMenu:")
    print("1. Say Hello")
    print("2. Calculate Square")
    print("3. Exit")

    choice = input("Enter your choice (1-3): ")

    if choice == '1':
        print("Hello there!")
    elif choice == '2':
        try:
            number = int(input("Enter a number: "))
            square = number ** 2
            print(f"The square of {number} is {square}")
        except ValueError:
            print("Invalid input. Please enter an integer.")
    elif choice == '3':
        print("Exiting...")
        break
    else:
        print("Invalid choice. Please enter a number between 1 and 3.")
# Out:
# Menu:
# 1. Say Hello
# 2. Calculate Square
# 3. Exit
# Enter your choice (1-3):  hello
# Invalid choice. Please enter a number between 1 and 3.
#
# Menu:
# 1. Say Hello
# 2. Calculate Square
# 3. Exit
# Enter your choice (1-3):  2
# Enter a number:  27
# The square of 27 is 729
#
# Menu:
# 1. Say Hello
# 2. Calculate Square
# 3. Exit
# Enter your choice (1-3):  3
# Exiting...

# %%
#Ask the user for a word and a number.
#Print the word right-aligned in a field of width 20, followed by the number.
name=str(input("enter the name: "))
number=int(input("enter the number: "))
print(f"{name:>20} {number}")
# Out:
# enter the name:  senthil
# enter the number:  27
#              senthil 27

# %%
#You have two lists: names = ["Alice", "Bob", "Charlie"] and scores = [85, 92, 78].
#Print these lists as a simple table with columns “Name” and “Score”.

names = ["Alice", "Bob", "Charlie"]
scores = [85, 92, 78]
print(f"{'Name':<10} {'Score':<5}")
print("-" * 15)
for name, score in zip(names, scores):
    print(f"{name:<10} {score:<5}")
# Out:
# Name       Score
# ---------------
# Alice      85
# Bob        92
# Charlie    78

# %%
#Ask the user for a number. Print this number padded with leading zeros to a width of 5.
number_str = input("Enter a number: ")
padded_number = number_str.zfill(5)
print(padded_number)
# Out:
# Enter a number:  10
# 00010
